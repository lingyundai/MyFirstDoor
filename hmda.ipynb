# %%
import requests
import csv

# HMDA data
url = "https://ffiec.cfpb.gov/v2/data-browser-api/view/nationwide/aggregations"
years = [2023, 2022, 2021, 2020]
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY","DC"]
# Dictionary to store results by state and year
state_yearly_data = {}

for state in states:
    state_yearly_data[state] = {}
    for year in years:
        total_approvals_for_year = 0
        total_applications_for_year = 0

        params = {
            "years": year,
            "states": state,
            "actions_taken": "1,2,3,4,5,6,7,8"  # Total applications
        }
        try:
            # GET request
            response = requests.get(url, params=params)
            # Print status code and response for debugging
            print(f"State {state}, Year {year} - Status code: {response.status_code}")
            # Check if the request was successful (status code 200)
            if response.status_code == 200:
                # Parse JSON response
                data = response.json()
                for entry in data.get('aggregations', []):
                    if entry.get('actions_taken') in ['1', '2']:
                        # Only count approvals
                        total_approvals_for_year += entry.get('count', 0)
                    # Count all applications
                    total_applications_for_year += entry.get('count', 0)
                # Store data for the year
                approval_rate = (total_approvals_for_year / total_applications_for_year) * 100 if total_applications_for_year > 0 else 0
                state_yearly_data[state][year] = {
                    "total_approvals": total_approvals_for_year,
                    "total_applications": total_applications_for_year,
                    "approval_rate": approval_rate
                }
                print(f"Data received for {state}, {year}: {state_yearly_data[state][year]}")
            else:
                print(f"Error for state {state}, year {year}: {response.status_code} {response.reason}")
        except requests.exceptions.RequestException as e:
            print(f"An error occurred for state {state}, year {year}: {e}")

# Write data to CSV file
csv_file = "hmda_data_all_states.csv"
with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    # Write the header
    writer.writerow(["State", "Year", "Total Approvals", "Total Applications", "Approval Rate"])
    # Write the data
    for state, yearly_data in state_yearly_data.items():
        for year, data in yearly_data.items():
            writer.writerow([state, year, data['total_approvals'], data['total_applications'], data['approval_rate']])

print(f"Data has been written to {csv_file}")
# Out:
# State AL, Year 2023 - Status code: 200
# Data received for AL, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State AL, Year 2022 - Status code: 200
# Data received for AL, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State AL, Year 2021 - Status code: 200
# Data received for AL, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State AL, Year 2020 - Status code: 200
# Data received for AL, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State AK, Year 2023 - Status code: 200
# Data received for AK, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State AK, Year 2022 - Status code: 200
# Data received for AK, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State AK, Year 2021 - Status code: 200
# Data received for AK, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State AK, Year 2020 - Status code: 200
# Data received for AK, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State AZ, Year 2023 - Status code: 200
# Data received for AZ, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State AZ, Year 2022 - Status code: 200
# Data received for AZ, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State AZ, Year 2021 - Status code: 200
# Data received for AZ, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State AZ, Year 2020 - Status code: 200
# Data received for AZ, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State AR, Year 2023 - Status code: 200
# Data received for AR, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State AR, Year 2022 - Status code: 200
# Data received for AR, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State AR, Year 2021 - Status code: 200
# Data received for AR, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State AR, Year 2020 - Status code: 200
# Data received for AR, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State CA, Year 2023 - Status code: 200
# Data received for CA, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State CA, Year 2022 - Status code: 200
# Data received for CA, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State CA, Year 2021 - Status code: 200
# Data received for CA, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State CA, Year 2020 - Status code: 200
# Data received for CA, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State CO, Year 2023 - Status code: 200
# Data received for CO, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State CO, Year 2022 - Status code: 200
# Data received for CO, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State CO, Year 2021 - Status code: 200
# Data received for CO, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State CO, Year 2020 - Status code: 200
# Data received for CO, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State CT, Year 2023 - Status code: 200
# Data received for CT, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State CT, Year 2022 - Status code: 200
# Data received for CT, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State CT, Year 2021 - Status code: 200
# Data received for CT, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State CT, Year 2020 - Status code: 200
# Data received for CT, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State DE, Year 2023 - Status code: 200
# Data received for DE, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State DE, Year 2022 - Status code: 200
# Data received for DE, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State DE, Year 2021 - Status code: 200
# Data received for DE, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State DE, Year 2020 - Status code: 200
# Data received for DE, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State FL, Year 2023 - Status code: 200
# Data received for FL, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State FL, Year 2022 - Status code: 200
# Data received for FL, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State FL, Year 2021 - Status code: 200
# Data received for FL, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State FL, Year 2020 - Status code: 200
# Data received for FL, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State GA, Year 2023 - Status code: 200
# Data received for GA, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State GA, Year 2022 - Status code: 200
# Data received for GA, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State GA, Year 2021 - Status code: 200
# Data received for GA, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State GA, Year 2020 - Status code: 200
# Data received for GA, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State HI, Year 2023 - Status code: 200
# Data received for HI, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State HI, Year 2022 - Status code: 200
# Data received for HI, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State HI, Year 2021 - Status code: 200
# Data received for HI, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State HI, Year 2020 - Status code: 200
# Data received for HI, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State ID, Year 2023 - Status code: 200
# Data received for ID, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State ID, Year 2022 - Status code: 200
# Data received for ID, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State ID, Year 2021 - Status code: 200
# Data received for ID, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State ID, Year 2020 - Status code: 200
# Data received for ID, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State IL, Year 2023 - Status code: 200
# Data received for IL, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State IL, Year 2022 - Status code: 200
# Data received for IL, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State IL, Year 2021 - Status code: 200
# Data received for IL, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State IL, Year 2020 - Status code: 200
# Data received for IL, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State IN, Year 2023 - Status code: 200
# Data received for IN, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State IN, Year 2022 - Status code: 200
# Data received for IN, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State IN, Year 2021 - Status code: 200
# Data received for IN, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State IN, Year 2020 - Status code: 200
# Data received for IN, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State IA, Year 2023 - Status code: 200
# Data received for IA, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State IA, Year 2022 - Status code: 200
# Data received for IA, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State IA, Year 2021 - Status code: 200
# Data received for IA, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State IA, Year 2020 - Status code: 200
# Data received for IA, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State KS, Year 2023 - Status code: 200
# Data received for KS, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State KS, Year 2022 - Status code: 200
# Data received for KS, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State KS, Year 2021 - Status code: 200
# Data received for KS, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State KS, Year 2020 - Status code: 200
# Data received for KS, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State KY, Year 2023 - Status code: 200
# Data received for KY, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State KY, Year 2022 - Status code: 200
# Data received for KY, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State KY, Year 2021 - Status code: 200
# Data received for KY, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State KY, Year 2020 - Status code: 200
# Data received for KY, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State LA, Year 2023 - Status code: 200
# Data received for LA, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State LA, Year 2022 - Status code: 200
# Data received for LA, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State LA, Year 2021 - Status code: 200
# Data received for LA, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State LA, Year 2020 - Status code: 200
# Data received for LA, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State ME, Year 2023 - Status code: 200
# Data received for ME, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State ME, Year 2022 - Status code: 200
# Data received for ME, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State ME, Year 2021 - Status code: 200
# Data received for ME, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State ME, Year 2020 - Status code: 200
# Data received for ME, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State MD, Year 2023 - Status code: 200
# Data received for MD, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State MD, Year 2022 - Status code: 200
# Data received for MD, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State MD, Year 2021 - Status code: 200
# Data received for MD, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State MD, Year 2020 - Status code: 200
# Data received for MD, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State MA, Year 2023 - Status code: 200
# Data received for MA, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State MA, Year 2022 - Status code: 200
# Data received for MA, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State MA, Year 2021 - Status code: 200
# Data received for MA, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State MA, Year 2020 - Status code: 200
# Data received for MA, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State MI, Year 2023 - Status code: 200
# Data received for MI, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State MI, Year 2022 - Status code: 200
# Data received for MI, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State MI, Year 2021 - Status code: 200
# Data received for MI, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State MI, Year 2020 - Status code: 200
# Data received for MI, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State MN, Year 2023 - Status code: 200
# Data received for MN, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State MN, Year 2022 - Status code: 200
# Data received for MN, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State MN, Year 2021 - Status code: 200
# Data received for MN, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State MN, Year 2020 - Status code: 200
# Data received for MN, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State MS, Year 2023 - Status code: 200
# Data received for MS, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State MS, Year 2022 - Status code: 200
# Data received for MS, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State MS, Year 2021 - Status code: 200
# Data received for MS, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State MS, Year 2020 - Status code: 200
# Data received for MS, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State MO, Year 2023 - Status code: 200
# Data received for MO, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State MO, Year 2022 - Status code: 200
# Data received for MO, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State MO, Year 2021 - Status code: 200
# Data received for MO, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State MO, Year 2020 - Status code: 200
# Data received for MO, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State MT, Year 2023 - Status code: 200
# Data received for MT, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State MT, Year 2022 - Status code: 200
# Data received for MT, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State MT, Year 2021 - Status code: 200
# Data received for MT, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State MT, Year 2020 - Status code: 200
# Data received for MT, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State NE, Year 2023 - Status code: 200
# Data received for NE, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State NE, Year 2022 - Status code: 200
# Data received for NE, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State NE, Year 2021 - Status code: 200
# Data received for NE, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State NE, Year 2020 - Status code: 200
# Data received for NE, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State NV, Year 2023 - Status code: 200
# Data received for NV, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State NV, Year 2022 - Status code: 200
# Data received for NV, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State NV, Year 2021 - Status code: 200
# Data received for NV, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State NV, Year 2020 - Status code: 200
# Data received for NV, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State NH, Year 2023 - Status code: 200
# Data received for NH, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State NH, Year 2022 - Status code: 200
# Data received for NH, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State NH, Year 2021 - Status code: 200
# Data received for NH, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State NH, Year 2020 - Status code: 200
# Data received for NH, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State NJ, Year 2023 - Status code: 200
# Data received for NJ, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State NJ, Year 2022 - Status code: 200
# Data received for NJ, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State NJ, Year 2021 - Status code: 200
# Data received for NJ, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State NJ, Year 2020 - Status code: 200
# Data received for NJ, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State NM, Year 2023 - Status code: 200
# Data received for NM, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State NM, Year 2022 - Status code: 200
# Data received for NM, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State NM, Year 2021 - Status code: 200
# Data received for NM, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State NM, Year 2020 - Status code: 200
# Data received for NM, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State NY, Year 2023 - Status code: 200
# Data received for NY, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State NY, Year 2022 - Status code: 200
# Data received for NY, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State NY, Year 2021 - Status code: 200
# Data received for NY, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State NY, Year 2020 - Status code: 200
# Data received for NY, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State NC, Year 2023 - Status code: 200
# Data received for NC, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State NC, Year 2022 - Status code: 200
# Data received for NC, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State NC, Year 2021 - Status code: 200
# Data received for NC, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State NC, Year 2020 - Status code: 200
# Data received for NC, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State ND, Year 2023 - Status code: 200
# Data received for ND, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State ND, Year 2022 - Status code: 200
# Data received for ND, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State ND, Year 2021 - Status code: 200
# Data received for ND, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State ND, Year 2020 - Status code: 200
# Data received for ND, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State OH, Year 2023 - Status code: 200
# Data received for OH, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State OH, Year 2022 - Status code: 200
# Data received for OH, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State OH, Year 2021 - Status code: 200
# Data received for OH, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State OH, Year 2020 - Status code: 200
# Data received for OH, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State OK, Year 2023 - Status code: 200
# Data received for OK, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State OK, Year 2022 - Status code: 200
# Data received for OK, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State OK, Year 2021 - Status code: 200
# Data received for OK, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State OK, Year 2020 - Status code: 200
# Data received for OK, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State OR, Year 2023 - Status code: 200
# Data received for OR, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State OR, Year 2022 - Status code: 200
# Data received for OR, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State OR, Year 2021 - Status code: 200
# Data received for OR, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State OR, Year 2020 - Status code: 200
# Data received for OR, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State PA, Year 2023 - Status code: 200
# Data received for PA, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State PA, Year 2022 - Status code: 200
# Data received for PA, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State PA, Year 2021 - Status code: 200
# Data received for PA, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State PA, Year 2020 - Status code: 200
# Data received for PA, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State RI, Year 2023 - Status code: 200
# Data received for RI, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State RI, Year 2022 - Status code: 200
# Data received for RI, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State RI, Year 2021 - Status code: 200
# Data received for RI, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State RI, Year 2020 - Status code: 200
# Data received for RI, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State SC, Year 2023 - Status code: 200
# Data received for SC, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State SC, Year 2022 - Status code: 200
# Data received for SC, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State SC, Year 2021 - Status code: 200
# Data received for SC, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State SC, Year 2020 - Status code: 200
# Data received for SC, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State SD, Year 2023 - Status code: 200
# Data received for SD, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State SD, Year 2022 - Status code: 200
# Data received for SD, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State SD, Year 2021 - Status code: 200
# Data received for SD, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State SD, Year 2020 - Status code: 200
# Data received for SD, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State TN, Year 2023 - Status code: 200
# Data received for TN, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State TN, Year 2022 - Status code: 200
# Data received for TN, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State TN, Year 2021 - Status code: 200
# Data received for TN, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State TN, Year 2020 - Status code: 200
# Data received for TN, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State TX, Year 2023 - Status code: 200
# Data received for TX, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State TX, Year 2022 - Status code: 200
# Data received for TX, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State TX, Year 2021 - Status code: 200
# Data received for TX, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State TX, Year 2020 - Status code: 200
# Data received for TX, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State UT, Year 2023 - Status code: 200
# Data received for UT, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State UT, Year 2022 - Status code: 200
# Data received for UT, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State UT, Year 2021 - Status code: 200
# Data received for UT, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State UT, Year 2020 - Status code: 200
# Data received for UT, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State VT, Year 2023 - Status code: 200
# Data received for VT, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State VT, Year 2022 - Status code: 200
# Data received for VT, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State VT, Year 2021 - Status code: 200
# Data received for VT, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State VT, Year 2020 - Status code: 200
# Data received for VT, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State VA, Year 2023 - Status code: 200
# Data received for VA, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State VA, Year 2022 - Status code: 200
# Data received for VA, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State VA, Year 2021 - Status code: 200
# Data received for VA, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State VA, Year 2020 - Status code: 200
# Data received for VA, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State WA, Year 2023 - Status code: 200
# Data received for WA, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State WA, Year 2022 - Status code: 200
# Data received for WA, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State WA, Year 2021 - Status code: 200
# Data received for WA, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State WA, Year 2020 - Status code: 200
# Data received for WA, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State WV, Year 2023 - Status code: 200
# Data received for WV, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State WV, Year 2022 - Status code: 200
# Data received for WV, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State WV, Year 2021 - Status code: 200
# Data received for WV, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State WV, Year 2020 - Status code: 200
# Data received for WV, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State WI, Year 2023 - Status code: 200
# Data received for WI, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State WI, Year 2022 - Status code: 200
# Data received for WI, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State WI, Year 2021 - Status code: 200
# Data received for WI, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State WI, Year 2020 - Status code: 200
# Data received for WI, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State WY, Year 2023 - Status code: 200
# Data received for WY, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State WY, Year 2022 - Status code: 200
# Data received for WY, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State WY, Year 2021 - Status code: 200
# Data received for WY, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State WY, Year 2020 - Status code: 200
# Data received for WY, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# State DC, Year 2023 - Status code: 200
# Data received for DC, 2023: {'total_approvals': 6000563, 'total_applications': 11483889, 'approval_rate': 52.25201149192578}
# State DC, Year 2022 - Status code: 200
# Data received for DC, 2022: {'total_approvals': 8823472, 'total_applications': 16099307, 'approval_rate': 54.806532976854214}
# State DC, Year 2021 - Status code: 200
# Data received for DC, 2021: {'total_approvals': 15697898, 'total_applications': 26227364, 'approval_rate': 59.853128968660364}
# State DC, Year 2020 - Status code: 200
# Data received for DC, 2020: {'total_approvals': 15298091, 'total_applications': 25699043, 'approval_rate': 59.527862574493525}
# Data has been written to hmda_data_all_states.csv
